# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create a graph
G = nx.Graph()

# Add nodes
G.add_nodes_from([1, 2, 3, 4, 5, 6, 7, 8])

# Add edges
G.add_edges_from([(1, 2), (1, 3), (2, 3), (3, 4), (4, 5), (5, 1), (4, 6), (7, 1), (3, 8), (2, 6), (1, 8)])

# Visualize the graph
nx.draw(G, with_labels=True)
plt.show()

# Find cliques
cliques = list(nx.find_cliques(G))
print("Cliques:", cliques)

# Calculate betweenness centrality
betweenness_centrality = nx.betweenness_centrality(G)
print("Betweenness centrality:", betweenness_centrality)

# Calculate density
density = nx.density(G)
print("Density:", density)

# Find bridges
bridges = list(nx.bridges(G))
print("Bridges:", bridges)

# Find the egocentric network
ego_net = nx.ego_graph(G, 1)
# Visualize the egocentric network
nx.draw(ego_net, with_labels=True)
plt.show()
# Out:
# Cliques: [[1, 3, 8], [1, 3, 2], [1, 5], [1, 7], [4, 3], [4, 5], [4, 6], [6, 2]]
# Betweenness centrality: {1: 0.4444444444444445, 2: 0.15079365079365079, 3: 0.17460317460317462, 4: 0.11111111111111109, 5: 0.047619047619047616, 6: 0.023809523809523808, 7: 0.0, 8: 0.0}
# Density: 0.39285714285714285
# Bridges: [(1, 7)]
